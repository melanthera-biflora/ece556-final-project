# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import GridSearchCV
import seaborn as sns
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from xgboost import XGBRegressor

# %%
training_data = pd.read_csv('/kaggle/input/mekong-training-testing-set/landsat7_train.csv')
testing_data = pd.read_csv('/kaggle/input/mekong-training-testing-set/landsat7_test.csv')

# %%
# Change the type into date time
def into_datetime(df):
    df['date'] = pd.to_datetime(df['date'])
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year

# %%
into_datetime(training_data)
into_datetime(testing_data)

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AWEInsh    56 non-null     float64
#  1   AWEIsh     56 non-null     float64
#  2   MNDWI      56 non-null     float64
#  3   NDWI       56 non-null     float64
#  4   SR_B1      56 non-null     float64
#  5   SR_B2      56 non-null     float64
#  6   SR_B3      56 non-null     float64
#  7   SR_B4      56 non-null     float64
#  8   SR_B5      56 non-null     float64
#  9   SR_B7      56 non-null     float64
#  10  ST_B6      56 non-null     float64
#  11  WI1        56 non-null     float64
#  12  WI2        56 non-null     float64
#  13  date       56 non-null     datetime64[ns]
#  14  pivot      56 non-null     int64
#  15  reducer    56 non-null     object
#  16  source     56 non-null     object
#  17  Station    56 non-null     object
#  18  Latitude   56 non-null     float64
#  19  Longitude  56 non-null     float64
#  20  1          56 non-null     float64
#  21  3          56 non-null     float64
#  22  5          56 non-null     float64
#  23  7          56 non-null     float64
#  24  9          56 non-null     float64
#  25  11         56 non-null     float64
#  26  13         56 non-null     float64
#  27  15         56 non-null     float64
#  28  17         56 non-null     float64
#  29  19         56 non-null     float64
#  30  21         56 non-null     float64
#  31  23         56 non-null     float64
#  32  min        56 non-null     float64
#  33  max        56 non-null     float64
#  34  mean       56 non-null     float64
#  35  median     56 non-null     float64
#  36  month      56 non-null     int32
#  37  year       56 non-null     int32
# dtypes: datetime64[ns](1), float64(31), int32(2), int64(1), object(3)
# memory usage: 16.3+ KB

# %%
testing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AWEInsh    11 non-null     float64
#  1   AWEIsh     11 non-null     float64
#  2   MNDWI      11 non-null     float64
#  3   NDWI       11 non-null     float64
#  4   SR_B1      11 non-null     float64
#  5   SR_B2      11 non-null     float64
#  6   SR_B3      11 non-null     float64
#  7   SR_B4      11 non-null     float64
#  8   SR_B5      11 non-null     float64
#  9   SR_B7      11 non-null     float64
#  10  ST_B6      11 non-null     float64
#  11  WI1        11 non-null     float64
#  12  WI2        11 non-null     float64
#  13  date       11 non-null     datetime64[ns]
#  14  pivot      11 non-null     int64
#  15  reducer    11 non-null     object
#  16  source     11 non-null     object
#  17  Station    11 non-null     object
#  18  Latitude   11 non-null     float64
#  19  Longitude  11 non-null     float64
#  20  1          11 non-null     float64
#  21  3          11 non-null     float64
#  22  5          11 non-null     float64
#  23  7          11 non-null     float64
#  24  9          11 non-null     float64
#  25  11         11 non-null     float64
#  26  13         11 non-null     float64
#  27  15         11 non-null     float64
#  28  17         11 non-null     float64
#  29  19         11 non-null     float64
#  30  21         11 non-null     float64
#  31  23         11 non-null     float64
#  32  min        11 non-null     float64
#  33  max        11 non-null     float64
#  34  mean       11 non-null     float64
#  35  median     11 non-null     float64
#  36  month      11 non-null     int32
#  37  year       11 non-null     int32
# dtypes: datetime64[ns](1), float64(31), int32(2), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
features = [ 'SR_B4', 'SR_B5', 'SR_B7',
    'ST_B6', 'WI1', 'WI2', 'month', 'year', 'Latitude', 'Longitude'
]

# %%
target = 'max'

# %%
# Split data
X_train = training_data[features]
y_train = training_data[target]
X_test = testing_data[features]
y_test = testing_data[target]

# %%
param_grid = {
    'n_estimators': [100, 120, 150],
    'max_depth': [2, 3],
    'learning_rate': [0.015, 0.02, 0.025],
    'subsample': [0.6, 0.7],
    'colsample_bytree': [0.6, 0.7],
    'reg_alpha': [0.5, 1, 2],
    'reg_lambda': [10, 20, 30]
}

# %%
# Initialize model
#xgb = XGBRegressor(objective='reg:squarederror', random_state=42)

# %%
grid_search = GridSearchCV(
    estimator=XGBRegressor(objective='reg:squarederror', random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_squared_error',
    verbose=2,
    n_jobs=-1
)

# %%
# Fit the model
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s[CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s[CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s[CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=2, n_estimators=150, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.015, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# ...
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=100, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=120, reg_alpha=2, reg_lambda=20, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=0.5, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=1, reg_lambda=30, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.025, max_depth=3, n_estimators=150, reg_alpha=2, reg_lambda=10, subsample=0.7; total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.7],
#                          'learning_rate': [0.015, 0.02, 0.025],
#                          'max_depth': [2, 3], 'n_estimators': [100, 120, 150],
#                          'reg_alpha': [0.5, 1, 2], 'reg_lambda': [10, 20, 30],
#                          'subsample': [0.6, 0.7]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
# Get best model
best_xgb = grid_search.best_estimator_
print("✅ Best parameters:", grid_search.best_params_)
# Out:
# ✅ Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.025, 'max_depth': 3, 'n_estimators': 150, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.6}

# %%
def wmape(y_true, y_pred):
    return 100 * np.sum(np.abs(y_true - y_pred)) / (np.sum(np.abs(y_true)) + 1e-8)

def evaluate_model(model, X, y, dataset_name=""):
    y_pred = model.predict(X)
    rmse = mean_squared_error(y, y_pred, squared=False)
    r2 = r2_score(y, y_pred)
    mae = mean_absolute_error(y, y_pred)
    wmape_score = wmape(y, y_pred)

    print(f"\n📊 Evaluation on {dataset_name} Set:")
    print(f"• RMSE  : {rmse:.4f}")
    print(f"• R²    : {r2:.4f}")
    print(f"• MAE   : {mae:.4f}")
    print(f"• WMAPE : {wmape_score:.2f}%")

# %%
# Evaluate on both sets
evaluate_model(best_xgb, X_train, y_train, "Training")
# Out:
# 📊 Evaluation on Training Set:
# • RMSE  : 3.6025
# • R²    : 0.7807
# • MAE   : 2.7997
# • WMAPE : 26.45%

# %%
evaluate_model(best_xgb, X_test, y_test, "Testing")
# Out:
# 📊 Evaluation on Testing Set:
# • RMSE  : 3.6385
# • R²    : 0.7372
# • MAE   : 3.1064
# • WMAPE : 41.88%
